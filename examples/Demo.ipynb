# %%
from datetime import datetime

def parse_date(d):
    return datetime.strptime(d['metadata']['date'], '%m/%d/%Y, %H:%M')

# %%
import sys  
sys.path.insert(1, '../')

# %% [markdown]
# # Define Objective of the Agent

# %%
raw_prompt = """
For each item that the buyer agreed to purchase, return the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item (quantity * (unit price - unit discount)) . Each sku of the purchased item should be treated as a separate item.

Output the result in JSON format following the example below. Each line item should have its own list under lineItems. Include all non quantity and price related details of each item under its description.

{ "orderDetails":{ "orderDate": "", "orderNum": null, }, "buyer":{ "companyName": "", "pointOfContact": "", "contactEmail": "", "contactPhone": "", "shippingAddress": "", }, "lineItems":[{ "itemNumber": null, "description": "", "quantity": null, "unitPrice": null, "discount": null, “totalPrice”: null}]}
"""

# %% [markdown]
# # Create a Midas Agent

# %%
from midas.agent import Midas

# %%
# %%time
new_agent = Midas('Sales Order Extractor')
new_agent.set_objective(raw_prompt)
new_agent.add_criteria(
    [
        {"format": "the format should be outputted as a single string representing a JSON object"},
        {"no_markdown": "the output should not be in markdown, it should not contain backticks"},
    ]
)
# Out:
# CPU times: user 124 ms, sys: 30.5 ms, total: 155 ms
# Wall time: 3.41 s

# %%
new_agent
# Out:
# Midas(Sales Order Extractor)
#
# Original User Prompt:
#
# For each item that the buyer agreed to purchase, return the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item (quantity * (unit price - unit discount)) . Each sku of the purchased item should be treated as a separate item.
#
# Output the result in JSON format following the example below. Each line item should have its own list under lineItems. Include all non quantity and price related details of each item under its description.
#
# { "orderDetails":{ "orderDate": "", "orderNum": null, }, "buyer":{ "companyName": "", "pointOfContact": "", "contactEmail": "", "contactPhone": "", "shippingAddress": "", }, "lineItems":[{ "itemNumber": null, "description": "", "quantity": null, "unitPrice": null, "discount": null, “totalPrice”: null}]}
#
#
# Subqueries:
#  - [orderDetails] orderDate, orderNum
#  - [buyer] companyName, pointOfContact, contactEmail, contactPhone, shippingAddress
#  - [lineItems] itemNumber, description, quantity, unitPrice, discount, totalPrice
#
# Agent Criteria:
#  - [Correctness] Ensure that each item the buyer agreed to purchase is included in the output.
#  - [Item Details] Provide the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item for each purchased item.
#  - [SKU Treatment] Treat each SKU of the purchased item as a separate item in the list.
#  - [Line Item Structure] Each line item should be structured as a dictionary with keys for itemNumber, description, quantity, unitPrice, discount, and totalPrice.
#  - [Order Details] Include orderDate and orderNum under orderDetails in the output.
#  - [Buyer Information] Include companyName, pointOfContact, contactEmail, contactPhone, and shippingAddress under buyer in the output.
#  - [JSON Format] Output the result in valid JSON format.
#  - [Accuracy of Calculations] Ensure the final total price per item is calculated correctly (quantity * (unit price - unit discount)).
#  - [Completeness] Include all non-quantity and price related details of each item under its description in the output.
#
# User Criteria:
#  - [format] the format should be outputted as a single string representing a JSON object
#  - [no_markdown] the output should not be in markdown, it should not contain backticks

# %% [markdown]
# # Run a Midas Agent

# %%
# %%time
result = new_agent.run(convo_id=0, sort_key=parse_date)
# Out:
# Running Midas(Sales Order Extractor) - convo_id=0
#
# User Request:
#
# For each item that the buyer agreed to purchase, return the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item (quantity * (unit price - unit discount)) . Each sku of the purchased item should be treated as a separate item.
#
# Output the result in JSON format following the example below. Each line item should have its own list under lineItems. Include all non quantity and price related details of each item under its description.
#
# { "orderDetails":{ "orderDate": "", "orderNum": null, }, "buyer":{ "companyName": "", "pointOfContact": "", "contactEmail": "", "contactPhone": "", "shippingAddress": "", }, "lineItems":[{ "itemNumber": null, "description": "", "quantity": null, "unitPrice": null, "discount": null, “totalPrice”: null}]}
#
#
# Criteria:
#
# Output Criteria:
#  - [format]: the format should be outputted as a single string representing a JSON object
#  - [no_markdown]: the output should not be in markdown, it should not contain backticks
#  - [Correctness]: Ensure that each item the buyer agreed to purchase is included in the output.
#  - [Item Details]: Provide the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item for each purchased item.
#  - [SKU Treatment]: Treat each SKU of the purchased item as a separate item in the list.
#  - [Line Item Structure]: Each line item should be structured as a dictionary with keys for itemNumber, description, quantity, unitPrice, discount, and totalPrice.
#  - [Order Details]: Include orderDate and orderNum under orderDetails in the output.
#  - [Buyer Information]: Include companyName, pointOfContact, contactEmail, contactPhone, and shippingAddress under buyer in the output.
#  - [JSON Format]: Output the result in valid JSON format.
#  - [Accuracy of Calculations]: Ensure the final total price per item is calculated correctly (quantity * (unit price - unit discount)).
#  - [Completeness]: Include all non-quantity and price related details of each item under its description in the output.
#
# Context Provided:
#
# ==================================================
# sender: richychentl@gmail.com
# receiver: mehulkhetrapal1@gmail.com
# date: 02/03/2024, 11:01
# convo_id: 0
# topics: ['orderDetails', 'lineItems']
#
# Hey Mehul,
# Hope you had a fruitful ASW.
# Here are our standard terms for manufacturing hoodies.
#
# |Cost|$10 per garment|
# |---|---|
# |Minimum order quantity|1000|
# |Turnaround|3 months|
# |Design service|Included|
#
# Best,
# Richy
#
# Mehul Khetrapal
#
# ==================================================
# sender: mehulkhetrapal1@gmail.com
# receiver: richychentl@gmail.com
# date: 02/03/2024, 11:02
# convo_id: 0
# topics: ['lineItems']
#
# Hey Richy,
# We are aiming for $7.50 per unit production. Can we remove the design service to get the price lower?
# [Quoted text hidden]
# --
# Mehul Khetrapal
# University of Southern California ‘20 ‘21
# B.S. Computational Neuroscience
# M.S. Biomedical Engineering
# https://www.linkedin.com/in/mehul-khetrapal/
#
# Richy Chen
#
# ==================================================
# sender: richychentl@gmail.com
# receiver: mehulkhetrapal1@gmail.com
# date: 02/03/2024, 11:04
# convo_id: 0
# topics: ['orderDetails', 'lineItems']
#
# We can remove the design service to give you a discount. I'm not sure we can do 7.50. Let me get back to you on that.
# Best,
# Richy
# [Quoted text hidden]
#
# Richy Chen
#
# ==================================================
# sender: richychentl@gmail.com
# receiver: mehulkhetrapal1@gmail.com
# date: 02/03/2024, 11:07
# convo_id: 0
# topics: ['orderDetails', 'buyer']
#
# OK, we can do $8
# [Quoted text hidden]
#
# Mehul Khetrapal <mehulkhetrapal1@gmail.com> - Sat, Feb 3, 2024 at 11:08 AM
#
# Link to the conversation
# ---
# 2/3/24, 11:09 AM                                                                     Gmail - ASW followup
#
# To: Richy Chen <richychentl@gmail.com>
#
# Hey Jerry!
#
# That works for us. Can you send over the contract?
#
# [Quoted text hidden]
#
# https://mail.google.com/mail/u/0/?ik=82f527275a&view=pt&search=all&permthid=thread-f:1789905488624882917&simpl=msg-f:1789905488624882917&simpl=…  2/2
#
# ==================================================
# sender: kevinsmith@llama.com
# receiver: hjacobs@tommybahama.com
# date: 02/03/2024, 19:29
# convo_id: 0
# topics: ['buyer']
#
# Hi Hannah,
#
# I trust this email finds you well. I wanted to express our gratitude for the informative and productive sales call we had recently. It was enlightening to learn more about the customization options and quality that Tommy Bahama offers.
#
# After discussing your proposal with the team at LlamaIndex, we are very interested in moving forward with the order for the 500 custom-made jackets. However, before we make any final commitments, we would appreciate it if the Tommy Bahama design team could provide us with some mock designs featuring the LlamaIndex logo and colors.
#
# We believe this step will not only give us a better visual understanding of how our branding elements will be incorporated into the jackets but will also help us make a more informed decision.
#
# Please let us know the timeframe within which we can expect to receive these mock designs.
#
# Additionally, considering the substantial quantity we are looking to order, we were wondering if there are any further discounts available for bulk purchases. We understand that you've already provided a first-time order discount of 20%, bringing the price per jacket down to $200, which we appreciate. However, given the volume of our order, we wanted to explore the possibility of additional incentives.
#
# We understand that the final price will depend on various factors, including design intricacies and shipping, but we'd like to ensure that we are maximizing the value of our investment.
#
# We are enthusiastic about the prospect of collaborating with Tommy Bahama on this project, and we believe that seeing the mock designs and discussing potential additional discounts will help us finalize our decision.
#
# Looking forward to your response and the next steps in our collaboration.
#
# Best regards,
#
# Kevin
#
# Llama Index
#
# Link to Email
# ---
# 2/3/24, 8:18 PM
#
# Gmail - Follow-Up and Further Details for LlamaIndex Jacket Order
#
# Hannah Jacobs
#
# ==================================================
# sender: hjacobs@tommybahama.com
# receiver: kevinsmith@llama.com
# date: 02/03/2024, 19:31
# convo_id: 0
# topics: ['buyer']
#
# Subject: Re: Follow-Up and Further Details for LlamaIndex Jacket Order
#
# Hi Kevin,
#
# Thank you for your prompt and thoughtful response. I'm delighted to hear that LlamaIndex is interested in moving forward with the custom jackets, and I appreciate your detailed considerations.
#
# I completely understand the importance of visualizing the final product, and I'll make sure to relay your request to our design team. They will work on creating mock designs with the LlamaIndex logo and colors. I anticipate having these ready for your review within the next week. Once they're prepared, I'll share them with you promptly.
#
# Regarding the possibility of a follow-up call, I suggest scheduling it for sometime next week to discuss the mock designs in detail and address any additional questions you might have. Here are a few time slots that work on my end:
#
# Tuesday at 10:00 AM
# Wednesday at 2:00 PM
# Thursday at 3:30 PM
#
# Please let me know which option suits your schedule, or propose an alternative time that would be convenient for you. I want to ensure that we find a time that works well for everyone involved.
#
# Additionally, I'll be reaching out to my manager to discuss the possibility of further pricing considerations for your bulk order. I understand the importance of making this investment worthwhile for LlamaIndex, and we'll do our best to accommodate your needs.
#
# Thank you once again for considering Tommy Bahama for this project. I'm looking forward to our continued collaboration and the opportunity to provide you with exceptional custom jackets.
#
# Best regards,
#
# Hannah
#
# [Quoted text hidden]
#
# Kevin Smith
#
# ==================================================
# sender: kevinsmith@llama.com
# receiver: hjacobs@tommybahama.com
# date: 02/03/2024, 19:32
# convo_id: 0
# topics: ['orderDetails', 'buyer']
#
# Lets do Wednesday at 2 pm! Looking forward to our chat!
#
# 2/5
# ---
# # Email
#
# 2/3/24, 8:18 PM
#
# Gmail - Follow-Up and Further Details for LlamaIndex Jacket Order
#
# [Quoted text hidden]
#
# From: Hannah Jacobs
#
# ==================================================
# sender: hjacobs@tommybahama.com
# receiver: kevinsmith@llama.com
# date: 02/03/2024, 20:01
# convo_id: 0
# topics: ['lineItems']
#
# Hi Kevin,
#
# I hope this email finds you well. Following our recent conversation about the custom jackets for LlamaIndex, I'm excited to share a sneak peek of the designs our team has mocked up based on your preferences. Attached to this email, you will find a selection of design options that feature the lively and fun elements we discussed – the light pink and light blue color scheme, the prominent LlamaIndex logo, and playful cactus and mountain graphics. Our design team has put a lot of effort into bringing your vision to life, and we're eager to hear your thoughts.
#
# Please take some time to review the attached designs and let us know if there are any specific elements you'd like to tweak or if you have additional ideas. Your feedback is invaluable, and we want to ensure the final design perfectly aligns with LlamaIndex's vision. Design 3 does come with a slight premium, due to it requiring additional ink in order to ensure maximum quality. The table below outlines the final pricing (with the included 1,000 jacket discount).
#
# |Design|Unit Price (500 jackets)|Unit Price (1,000 jackets)|
# |---|---|---|
# |Design 1 (Cactus)|200|160|
# |Design 2 (Mountain)|200|160|
# |Design 3 (Cactus & Mountain)|250|200|
#
# Additionally, I want to remind you of our scheduled follow-up call next Thursday at 2:30 PM, where we can discuss the designs in more detail and finalize any remaining details. If there are any changes or adjustments you'd like to propose, we're more than happy to accommodate them. Your satisfaction is our priority, and we appreciate your collaboration in refining these designs to meet your expectations. If you have any questions or feedback, please don't hesitate to reach out. We're here to make sure the end result is exactly what LlamaIndex envisions.
#
# Link to Gmail
# ---
# Thank you for choosing Tommy Bahama for this project, Kevin. We're looking forward to hearing your thoughts and working together towards the perfect custom jackets.
#
# Best regards,
#
# Hannah
#
# Tommy Bahama Sales Representative
#
# [Attachments: LlamaIndex_Jacket_Designs_Preview.pdf]
#
# [Quoted text hidden]
#
# Kevin Smith
#
# Agent Output:
#
# {
#   "orderDetails": {
#     "orderDate": "02/03/2024",
#     "orderNum": null
#   },
#   "buyer": {
#     "companyName": "Llama Index",
#     "pointOfContact": "Kevin Smith",
#     "contactEmail": "kevinsmith@llama.com",
#     "contactPhone": "",
#     "shippingAddress": ""
#   },
#   "lineItems": [
#     {
#       "itemNumber": null,
#       "description": "Custom Jacket - Design 1 (Cactus)",
#       "quantity": 500,
#       "unitPrice": 200,
#       "discount": 0,
#       "totalPrice": 100000
#     },
#     {
#       "itemNumber": null,
#       "description": "Custom Jacket - Design 2 (Mountain)",
#       "quantity": 500,
#       "unitPrice": 200,
#       "discount": 0,
#       "totalPrice": 100000
#     },
#     {
#       "itemNumber": null,
#       "description": "Custom Jacket - Design 3 (Cactus & Mountain)",
#       "quantity": 500,
#       "unitPrice": 250,
#       "discount": 0,
#       "totalPrice": 125000
#     }
#   ]
# }
# CPU times: user 103 ms, sys: 27.7 ms, total: 131 ms
# Wall time: 5.5 s

# %% [markdown]
# # Train a Midas Agent

# %%
# %%time
new_agent.train(convo_ids=[1, 0], sort_key=parse_date)
# Out:
# *********************************************
# *   Training Midas(Sales Order Extractor)   *
# *********************************************
#
# Running Midas(Sales Order Extractor) - convo_id=1
#
# User Request:
#
# For each item that the buyer agreed to purchase, return the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item (quantity * (unit price - unit discount)) . Each sku of the purchased item should be treated as a separate item.
#
# Output the result in JSON format following the example below. Each line item should have its own list under lineItems. Include all non quantity and price related details of each item under its description.
#
# { "orderDetails":{ "orderDate": "", "orderNum": null, }, "buyer":{ "companyName": "", "pointOfContact": "", "contactEmail": "", "contactPhone": "", "shippingAddress": "", }, "lineItems":[{ "itemNumber": null, "description": "", "quantity": null, "unitPrice": null, "discount": null, “totalPrice”: null}]}
#
#
# Criteria:
#
# Output Criteria:
#  - [format]: the format should be outputted as a single string representing a JSON object
#  - [no_markdown]: the output should not be in markdown, it should not contain backticks
#  - [Correctness]: Ensure that each item the buyer agreed to purchase is included in the output.
#  - [Item Details]: Provide the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item for each purchased item.
#  - [SKU Treatment]: Treat each SKU of the purchased item as a separate item in the list.
#  - [Line Item Structure]: Each line item should be structured as a dictionary with keys for itemNumber, description, quantity, unitPrice, discount, and totalPrice.
#  - [Order Details]: Include orderDate and orderNum under orderDetails in the output.
#  - [Buyer Information]: Include companyName, pointOfContact, contactEmail, contactPhone, and shippingAddress under buyer in the output.
#  - [JSON Format]: Output the result in valid JSON format.
#  - [Accuracy of Calculations]: Ensure the final total price per item is calculated correctly (quantity * (unit price - unit discount)).
#  - [Completeness]: Include all non-quantity and price related details of each item under its description in the output.
#
# Context Provided:
#
# ==================================================
# sender: hagoromorphism@gmail.com
# receiver: shahmohnish@gmail.com
# date: 02/03/2024, 11:09
# convo_id: 1
# topics: ['orderDetails', 'buyer', 'lineItems']
#
# Dear AllSaints,
#
# I hope this email finds you well. I am reaching out on behalf of LlamaIndex, the organizers of the upcoming LlamaIndex Hackathon. We are interested in purchasing custom-branded hoodies for our event participants.
#
# Our order includes 15 small, 15 medium, and 20 large hoodies, with the LlamaIndex branding.
#
# We have reviewed your catalog and are particularly interested in three different colors: light blue, pink, and a combination of blue and pink.
#
# Could you please provide a quote for each hoodie in these colors? Additionally, we would like to inquire if there is room for negotiation on the pricing, considering the quantity of hoodies we plan to order.
#
# Thank you for your time, and we look forward to your response.
#
# Best regards,
#
# LlamaIndex
#
# ### Message 2
#
# From: Mohnish Shah
#
# ==================================================
# sender: shahmohnish@gmail.com
# receiver: hagoromorphism@gmail.com
# date: 02/03/2024, 11:20
# convo_id: 1
# topics: ['orderDetails', 'buyer', 'lineItems']
#
# Dear AllSaints,
#
# Thank you for considering AllSaints for your custom-branded hoodies. We are thrilled to be a part of the LlamaIndex Hackathon.
#
# Page 1 of 3
# ---
# Gmail - Custom Branded Jacket Order
#
# Date: 2/3/24, 11:24 AM
#
# |Hoodie Color|Unit Price|
# |---|---|
# |Light Blue|$200|
# |Pink|$250|
# |Blue and Pink Multi-Colored|$300|
#
# To address your inquiry on pricing, we are pleased to offer a first-time purchase discount:
#
# For the Blue and Pink Multi-Colored Hoodies: 10% discount per hoodie
# For the Light Blue and Pink Hoodies: 20% discount per hoodie
# Waived shipping fee
#
# Discounted prices:
#
# |Hoodie Color|Discount|Discounted Price per Hoodie|
# |---|---|---|
# |Light Blue|20%|$160|
# |Pink|20%|$200|
# |Blue and Pink Multi-Colored|10%|$270|
#
# We hope these revised prices are within your budget. If you find them acceptable, please let us know, and we can proceed with finalizing the details of your order.
#
# Thank you for choosing AllSaints, and we look forward to contributing to the success of the LlamaIndex Hackathon.
#
# Best regards,
#
# AllSaints
#
# Page 2 of 3
# ---
# Gmail - Custom Branded Jacket Order
#
# 2/3/24, 11:24 AM
#
# From: Hagoromo Chalk
#
# ==================================================
# sender: hagoromorphism@gmail.com
# receiver: shahmohnish@gmail.com
# date: 02/03/2024, 11:21
# convo_id: 1
# topics: ['orderDetails', 'buyer', 'lineItems']
#
# Dear AllSaints,
#
# Thank you for your detailed response and the breakdown of the pricing. We appreciate your willingness to offer a discount for our order.
#
# After careful consideration, we are pleased to accept the offer for the Blue and Pink Multi-Colored Hoodies at the discounted price of $270 per hoodie. We wish to purchase 15 small, 15 medium, and 20 large hoodies. We believe this will be a great addition to our event.
#
# Please provide us with the necessary information and steps to proceed with the order.
#
# We are excited to showcase these custom-branded hoodies at the LlamaIndex Hackathon.
#
# Looking forward to a successful collaboration.
#
# Best regards,
#
# LlamaIndex
#
# [Quoted text hidden]
#
# Page 3 of 3
#
# Agent Output:
#
# {
#   "orderDetails": {
#     "orderDate": "02/03/2024",
#     "orderNum": null
#   },
#   "buyer": {
#     "companyName": "LlamaIndex",
#     "pointOfContact": "Mohnish Shah",
#     "contactEmail": "shahmohnish@gmail.com",
#     "contactPhone": "",
#     "shippingAddress": ""
#   },
#   "lineItems": [
#     {
#       "itemNumber": null,
#       "description": "Custom-branded Blue and Pink Multi-Colored Hoodie",
#       "quantity": 15,
#       "unitPrice": 300,
#       "discount": 30,
#       "totalPrice": 4050
#     },
#     {
#       "itemNumber": null,
#       "description": "Custom-branded Blue and Pink Multi-Colored Hoodie",
#       "quantity": 15,
#       "unitPrice": 300,
#       "discount": 30,
#       "totalPrice": 4050
#     },
#     {
#       "itemNumber": null,
#       "description": "Custom-branded Blue and Pink Multi-Colored Hoodie",
#       "quantity": 20,
#       "unitPrice": 300,
#       "discount": 30,
#       "totalPrice": 5400
#     }
#   ]
# }
#
# Midas Feedback:
#
# The output provided meets all the criteria specified:
#
# - The format is a single string representing a JSON object.
# - The output is not in markdown.
# - Each item the buyer agreed to purchase is included in the output.
# - Item details such as item name, description, quantity, unit price, unit discount, and final total price per item are all included.
# - Each SKU of the purchased item is treated as a separate item in the list.
# - Each line item is structured correctly with keys for itemNumber, description, quantity, unitPrice, discount, and totalPrice.
# - Order details (orderDate and orderNum) are included under orderDetails.
# - Buyer information (companyName, pointOfContact, contactEmail, contactPhone, shippingAddress) is included under buyer.
# - The output is in valid JSON format.
# - The calculations for the final total price per item (quantity * (unit price - unit discount)) are accurate.
# - All non-quantity and price related details of each item are included under its description.
#
# Overall, the output is comprehensive and fulfills all the specified criteria. Well done!
#
# Modified User Prompt:
#
# For each item that the buyer agreed to purchase, provide the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item (quantity * (unit price - unit discount)). Treat each SKU of the purchased item as a separate item. Output the result in JSON format as shown below. Each line item should be structured with keys for itemNumber, description, quantity, unitPrice, discount, and totalPrice. Include all non-quantity and price related details of each item under its description. Ensure that order details (orderDate and orderNum) are included under orderDetails, and buyer information (companyName, pointOfContact, contactEmail, contactPhone, shippingAddress) is included under buyer. The calculations for the final total price per item should be accurate.
#
# Running Midas(Sales Order Extractor) - convo_id=0
#
# User Request:
# For each item that the buyer agreed to purchase, provide the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item (quantity * (unit price - unit discount)). Treat each SKU of the purchased item as a separate item. Output the result in JSON format as shown below. Each line item should be structured with keys for itemNumber, description, quantity, unitPrice, discount, and totalPrice. Include all non-quantity and price related details of each item under its description. Ensure that order details (orderDate and orderNum) are included under orderDetails, and buyer information (companyName, pointOfContact, contactEmail, contactPhone, shippingAddress) is included under buyer. The calculations for the final total price per item should be accurate.
#
# Criteria:
#
# Output Criteria:
#  - [format]: the format should be outputted as a single string representing a JSON object
#  - [no_markdown]: the output should not be in markdown, it should not contain backticks
#  - [Correctness]: Ensure that each item the buyer agreed to purchase is included in the output.
#  - [Item Details]: Provide the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item for each purchased item.
#  - [SKU Treatment]: Treat each SKU of the purchased item as a separate item in the list.
#  - [Line Item Structure]: Each line item should be structured as a dictionary with keys for itemNumber, description, quantity, unitPrice, discount, and totalPrice.
#  - [Order Details]: Include orderDate and orderNum under orderDetails in the output.
#  - [Buyer Information]: Include companyName, pointOfContact, contactEmail, contactPhone, and shippingAddress under buyer in the output.
#  - [JSON Format]: Output the result in valid JSON format.
#  - [Accuracy of Calculations]: Ensure the final total price per item is calculated correctly (quantity * (unit price - unit discount)).
#  - [Completeness]: Include all non-quantity and price related details of each item under its description in the output.
#
# Context Provided:
#
# ==================================================
# sender: richychentl@gmail.com
# receiver: mehulkhetrapal1@gmail.com
# date: 02/03/2024, 11:01
# convo_id: 0
# topics: ['orderDetails', 'lineItems']
#
# Hey Mehul,
# Hope you had a fruitful ASW.
# Here are our standard terms for manufacturing hoodies.
#
# |Cost|$10 per garment|
# |---|---|
# |Minimum order quantity|1000|
# |Turnaround|3 months|
# |Design service|Included|
#
# Best,
# Richy
#
# Mehul Khetrapal
#
# ==================================================
# sender: mehulkhetrapal1@gmail.com
# receiver: richychentl@gmail.com
# date: 02/03/2024, 11:02
# convo_id: 0
# topics: ['lineItems']
#
# Hey Richy,
# We are aiming for $7.50 per unit production. Can we remove the design service to get the price lower?
# [Quoted text hidden]
# --
# Mehul Khetrapal
# University of Southern California ‘20 ‘21
# B.S. Computational Neuroscience
# M.S. Biomedical Engineering
# https://www.linkedin.com/in/mehul-khetrapal/
#
# Richy Chen
#
# ==================================================
# sender: richychentl@gmail.com
# receiver: mehulkhetrapal1@gmail.com
# date: 02/03/2024, 11:04
# convo_id: 0
# topics: ['orderDetails', 'lineItems']
#
# We can remove the design service to give you a discount. I'm not sure we can do 7.50. Let me get back to you on that.
# Best,
# Richy
# [Quoted text hidden]
#
# Richy Chen
#
# ==================================================
# sender: richychentl@gmail.com
# receiver: mehulkhetrapal1@gmail.com
# date: 02/03/2024, 11:07
# convo_id: 0
# topics: ['orderDetails', 'buyer']
#
# OK, we can do $8
# [Quoted text hidden]
#
# Mehul Khetrapal <mehulkhetrapal1@gmail.com> - Sat, Feb 3, 2024 at 11:08 AM
#
# Link to the conversation
# ---
# 2/3/24, 11:09 AM                                                                     Gmail - ASW followup
#
# To: Richy Chen <richychentl@gmail.com>
#
# Hey Jerry!
#
# That works for us. Can you send over the contract?
#
# [Quoted text hidden]
#
# https://mail.google.com/mail/u/0/?ik=82f527275a&view=pt&search=all&permthid=thread-f:1789905488624882917&simpl=msg-f:1789905488624882917&simpl=…  2/2
#
# ==================================================
# sender: kevinsmith@llama.com
# receiver: hjacobs@tommybahama.com
# date: 02/03/2024, 19:29
# convo_id: 0
# topics: ['buyer']
#
# Hi Hannah,
#
# I trust this email finds you well. I wanted to express our gratitude for the informative and productive sales call we had recently. It was enlightening to learn more about the customization options and quality that Tommy Bahama offers.
#
# After discussing your proposal with the team at LlamaIndex, we are very interested in moving forward with the order for the 500 custom-made jackets. However, before we make any final commitments, we would appreciate it if the Tommy Bahama design team could provide us with some mock designs featuring the LlamaIndex logo and colors.
#
# We believe this step will not only give us a better visual understanding of how our branding elements will be incorporated into the jackets but will also help us make a more informed decision.
#
# Please let us know the timeframe within which we can expect to receive these mock designs.
#
# Additionally, considering the substantial quantity we are looking to order, we were wondering if there are any further discounts available for bulk purchases. We understand that you've already provided a first-time order discount of 20%, bringing the price per jacket down to $200, which we appreciate. However, given the volume of our order, we wanted to explore the possibility of additional incentives.
#
# We understand that the final price will depend on various factors, including design intricacies and shipping, but we'd like to ensure that we are maximizing the value of our investment.
#
# We are enthusiastic about the prospect of collaborating with Tommy Bahama on this project, and we believe that seeing the mock designs and discussing potential additional discounts will help us finalize our decision.
#
# Looking forward to your response and the next steps in our collaboration.
#
# Best regards,
#
# Kevin
#
# Llama Index
#
# Link to Email
# ---
# 2/3/24, 8:18 PM
#
# Gmail - Follow-Up and Further Details for LlamaIndex Jacket Order
#
# Hannah Jacobs
#
# ==================================================
# sender: hjacobs@tommybahama.com
# receiver: kevinsmith@llama.com
# date: 02/03/2024, 19:31
# convo_id: 0
# topics: ['buyer']
#
# Subject: Re: Follow-Up and Further Details for LlamaIndex Jacket Order
#
# Hi Kevin,
#
# Thank you for your prompt and thoughtful response. I'm delighted to hear that LlamaIndex is interested in moving forward with the custom jackets, and I appreciate your detailed considerations.
#
# I completely understand the importance of visualizing the final product, and I'll make sure to relay your request to our design team. They will work on creating mock designs with the LlamaIndex logo and colors. I anticipate having these ready for your review within the next week. Once they're prepared, I'll share them with you promptly.
#
# Regarding the possibility of a follow-up call, I suggest scheduling it for sometime next week to discuss the mock designs in detail and address any additional questions you might have. Here are a few time slots that work on my end:
#
# Tuesday at 10:00 AM
# Wednesday at 2:00 PM
# Thursday at 3:30 PM
#
# Please let me know which option suits your schedule, or propose an alternative time that would be convenient for you. I want to ensure that we find a time that works well for everyone involved.
#
# Additionally, I'll be reaching out to my manager to discuss the possibility of further pricing considerations for your bulk order. I understand the importance of making this investment worthwhile for LlamaIndex, and we'll do our best to accommodate your needs.
#
# Thank you once again for considering Tommy Bahama for this project. I'm looking forward to our continued collaboration and the opportunity to provide you with exceptional custom jackets.
#
# Best regards,
#
# Hannah
#
# [Quoted text hidden]
#
# Kevin Smith
#
# ==================================================
# sender: kevinsmith@llama.com
# receiver: hjacobs@tommybahama.com
# date: 02/03/2024, 19:32
# convo_id: 0
# topics: ['orderDetails', 'buyer']
#
# Lets do Wednesday at 2 pm! Looking forward to our chat!
#
# 2/5
# ---
# # Email
#
# 2/3/24, 8:18 PM
#
# Gmail - Follow-Up and Further Details for LlamaIndex Jacket Order
#
# [Quoted text hidden]
#
# From: Hannah Jacobs
#
# ==================================================
# sender: hjacobs@tommybahama.com
# receiver: kevinsmith@llama.com
# date: 02/03/2024, 20:01
# convo_id: 0
# topics: ['lineItems']
#
# Hi Kevin,
#
# I hope this email finds you well. Following our recent conversation about the custom jackets for LlamaIndex, I'm excited to share a sneak peek of the designs our team has mocked up based on your preferences. Attached to this email, you will find a selection of design options that feature the lively and fun elements we discussed – the light pink and light blue color scheme, the prominent LlamaIndex logo, and playful cactus and mountain graphics. Our design team has put a lot of effort into bringing your vision to life, and we're eager to hear your thoughts.
#
# Please take some time to review the attached designs and let us know if there are any specific elements you'd like to tweak or if you have additional ideas. Your feedback is invaluable, and we want to ensure the final design perfectly aligns with LlamaIndex's vision. Design 3 does come with a slight premium, due to it requiring additional ink in order to ensure maximum quality. The table below outlines the final pricing (with the included 1,000 jacket discount).
#
# |Design|Unit Price (500 jackets)|Unit Price (1,000 jackets)|
# |---|---|---|
# |Design 1 (Cactus)|200|160|
# |Design 2 (Mountain)|200|160|
# |Design 3 (Cactus & Mountain)|250|200|
#
# Additionally, I want to remind you of our scheduled follow-up call next Thursday at 2:30 PM, where we can discuss the designs in more detail and finalize any remaining details. If there are any changes or adjustments you'd like to propose, we're more than happy to accommodate them. Your satisfaction is our priority, and we appreciate your collaboration in refining these designs to meet your expectations. If you have any questions or feedback, please don't hesitate to reach out. We're here to make sure the end result is exactly what LlamaIndex envisions.
#
# Link to Gmail
# ---
# Thank you for choosing Tommy Bahama for this project, Kevin. We're looking forward to hearing your thoughts and working together towards the perfect custom jackets.
#
# Best regards,
#
# Hannah
#
# Tommy Bahama Sales Representative
#
# [Attachments: LlamaIndex_Jacket_Designs_Preview.pdf]
#
# [Quoted text hidden]
#
# Kevin Smith
#
# Agent Output:
#
# {
#     "lineItems": [
#         {
#             "itemNumber": 1,
#             "description": {
#                 "item_name": "Custom Jacket - Design 1 (Cactus)",
#                 "item_description": "Custom-made jackets featuring a cactus design with light pink and light blue color scheme and the LlamaIndex logo.",
#                 "unitPrice": 200,
#                 "discount": 0,
#                 "finalPrice": 200
#             },
#             "quantity": 500
#         },
#         {
#             "itemNumber": 2,
#             "description": {
#                 "item_name": "Custom Jacket - Design 1 (Cactus)",
#                 "item_description": "Custom-made jackets featuring a cactus design with light pink and light blue color scheme and the LlamaIndex logo.",
#                 "unitPrice": 160,
#                 "discount": 0,
#                 "finalPrice": 160
#             },
#             "quantity": 1000
#         },
#         {
#             "itemNumber": 3,
#             "description": {
#                 "item_name": "Custom Jacket - Design 2 (Mountain)",
#                 "item_description": "Custom-made jackets featuring a mountain design with light pink and light blue color scheme and the LlamaIndex logo.",
#                 "unitPrice": 200,
#                 "discount": 0,
#                 "finalPrice": 200
#             },
#             "quantity": 500
#         },
#         {
#             "itemNumber": 4,
#             "description": {
#                 "item_name": "Custom Jacket - Design 2 (Mountain)",
#                 "item_description": "Custom-made jackets featuring a mountain design with light pink and light blue color scheme and the LlamaIndex logo.",
#                 "unitPrice": 160,
#                 "discount": 0,
#                 "finalPrice": 160
#             },
#             "quantity": 1000
#         },
#         {
#             "itemNumber": 5,
#             "description": {
#                 "item_name": "Custom Jacket - Design 3 (Cactus & Mountain)",
#                 "item_description": "Custom-made jackets featuring both cactus and mountain designs with light pink and light blue color scheme and the LlamaIndex logo. Design 3 comes with a slight premium due to requiring additional ink for maximum quality.",
#                 "unitPrice": 250,
#                 "discount": 0,
#                 "finalPrice": 250
#             },
#             "quantity": 500
#         },
#         {
#             "itemNumber": 6,
#             "description": {
#                 "item_name": "Custom Jacket - Design 3 (Cactus & Mountain)",
#                 "item_description": "Custom-made jackets featuring both cactus and mountain designs with light pink and light blue color scheme and the LlamaIndex logo. Design 3 comes with a slight premium due to requiring additional ink for maximum quality.",
#                 "unitPrice": 200,
#                 "discount": 0,
#                 "finalPrice": 200
#             },
#             "quantity": 1000
#         }
#     ],
#     "orderDetails": {
#         "orderDate": "02/03/2024",
#         "orderNum": "N/A"
#     },
#     "buyer": {
#         "companyName": "Llama Index",
#         "pointOfContact": "Kevin Smith",
#         "contactEmail": "kevinsmith@llama.com",
#         "contactPhone": "N/A",
#         "shippingAddress": "N/A"
#     }
# }
#
# Midas Feedback:
#
# The output meets all the specified criteria provided in the evaluation list:
#
# - The format is a single string representing a JSON object.
# - The output is not in markdown and does not contain backticks.
# - Each item the buyer agreed to purchase is included in the output.
# - For each purchased item, the item name, item description, quantity purchased, unit price, unit discount, and final total price per item are provided.
# - Each SKU of the purchased item is treated as a separate item in the list.
# - Each line item is structured as a dictionary with keys for itemNumber, description, quantity, unitPrice, discount, and totalPrice.
# - Order details (orderDate and orderNum) are included under orderDetails.
# - Buyer information (companyName, pointOfContact, contactEmail, contactPhone, shippingAddress) is included under buyer.
# - The output is in valid JSON format.
# - The final total price per item is calculated correctly (quantity * (unit price - unit discount)).
# - All non-quantity and price related details of each item are included under its description.
#
# Overall, the output is comprehensive and accurate based on the provided criteria.
#
# Modified User Prompt:
#
# For each item that the buyer agreed to purchase, provide the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item (quantity * (unit price - unit discount)). Treat each SKU of the purchased item as a separate item. Output the result in JSON format. Each line item should be structured with keys for itemNumber, description, quantity, unitPrice, discount, and totalPrice. Include all non-quantity and price related details of each item under its description. Ensure that order details (orderDate and orderNum) are included under orderDetails, and buyer information (companyName, pointOfContact, contactEmail, contactPhone, shippingAddress) is included under buyer. The final total price per item should be calculated accurately.
#
# **************
# Training Done!
# **************
# CPU times: user 204 ms, sys: 58.4 ms, total: 262 ms
# Wall time: 20.2 s

# %% [markdown]
# # Save a Midas Agent

# %%
# %%time
new_agent.save('../saved_agents/trained_midas_agent.json')
# Out:
# CPU times: user 4.61 ms, sys: 3.29 ms, total: 7.9 ms
# Wall time: 5.48 ms

# %% [markdown]
# # Load a Midas Agent

# %%
# %%time
trained_agent = Midas()
trained_agent.load('../saved_agents/trained_midas_agent.json')
# Out:
# CPU times: user 17.8 ms, sys: 6.17 ms, total: 24 ms
# Wall time: 25.8 ms

# %%
# %%time
result = new_agent.run(convo_id=1, sort_key=parse_date)
# Out:
# Running Midas(Sales Order Extractor) - convo_id=1
#
# User Request:
# For each item that the buyer agreed to purchase, provide the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item (quantity * (unit price - unit discount)). Treat each SKU of the purchased item as a separate item. Output the result in JSON format. Each line item should be structured with keys for itemNumber, description, quantity, unitPrice, discount, and totalPrice. Include all non-quantity and price related details of each item under its description. Ensure that order details (orderDate and orderNum) are included under orderDetails, and buyer information (companyName, pointOfContact, contactEmail, contactPhone, shippingAddress) is included under buyer. The final total price per item should be calculated accurately.
#
# Criteria:
#
# Output Criteria:
#  - [format]: the format should be outputted as a single string representing a JSON object
#  - [no_markdown]: the output should not be in markdown, it should not contain backticks
#  - [Correctness]: Ensure that each item the buyer agreed to purchase is included in the output.
#  - [Item Details]: Provide the item name, item description, quantity purchased, unit price in dollars, unit discount in dollars, and final total price per item for each purchased item.
#  - [SKU Treatment]: Treat each SKU of the purchased item as a separate item in the list.
#  - [Line Item Structure]: Each line item should be structured as a dictionary with keys for itemNumber, description, quantity, unitPrice, discount, and totalPrice.
#  - [Order Details]: Include orderDate and orderNum under orderDetails in the output.
#  - [Buyer Information]: Include companyName, pointOfContact, contactEmail, contactPhone, and shippingAddress under buyer in the output.
#  - [JSON Format]: Output the result in valid JSON format.
#  - [Accuracy of Calculations]: Ensure the final total price per item is calculated correctly (quantity * (unit price - unit discount)).
#  - [Completeness]: Include all non-quantity and price related details of each item under its description in the output.
#
# Context Provided:
#
# ==================================================
# sender: hagoromorphism@gmail.com
# receiver: shahmohnish@gmail.com
# date: 02/03/2024, 11:09
# convo_id: 1
# topics: ['orderDetails', 'buyer', 'lineItems']
#
# Dear AllSaints,
#
# I hope this email finds you well. I am reaching out on behalf of LlamaIndex, the organizers of the upcoming LlamaIndex Hackathon. We are interested in purchasing custom-branded hoodies for our event participants.
#
# Our order includes 15 small, 15 medium, and 20 large hoodies, with the LlamaIndex branding.
#
# We have reviewed your catalog and are particularly interested in three different colors: light blue, pink, and a combination of blue and pink.
#
# Could you please provide a quote for each hoodie in these colors? Additionally, we would like to inquire if there is room for negotiation on the pricing, considering the quantity of hoodies we plan to order.
#
# Thank you for your time, and we look forward to your response.
#
# Best regards,
#
# LlamaIndex
#
# ### Message 2
#
# From: Mohnish Shah
#
# ==================================================
# sender: shahmohnish@gmail.com
# receiver: hagoromorphism@gmail.com
# date: 02/03/2024, 11:20
# convo_id: 1
# topics: ['orderDetails', 'buyer', 'lineItems']
#
# Dear AllSaints,
#
# Thank you for considering AllSaints for your custom-branded hoodies. We are thrilled to be a part of the LlamaIndex Hackathon.
#
# Page 1 of 3
# ---
# Gmail - Custom Branded Jacket Order
#
# Date: 2/3/24, 11:24 AM
#
# |Hoodie Color|Unit Price|
# |---|---|
# |Light Blue|$200|
# |Pink|$250|
# |Blue and Pink Multi-Colored|$300|
#
# To address your inquiry on pricing, we are pleased to offer a first-time purchase discount:
#
# For the Blue and Pink Multi-Colored Hoodies: 10% discount per hoodie
# For the Light Blue and Pink Hoodies: 20% discount per hoodie
# Waived shipping fee
#
# Discounted prices:
#
# |Hoodie Color|Discount|Discounted Price per Hoodie|
# |---|---|---|
# |Light Blue|20%|$160|
# |Pink|20%|$200|
# |Blue and Pink Multi-Colored|10%|$270|
#
# We hope these revised prices are within your budget. If you find them acceptable, please let us know, and we can proceed with finalizing the details of your order.
#
# Thank you for choosing AllSaints, and we look forward to contributing to the success of the LlamaIndex Hackathon.
#
# Best regards,
#
# AllSaints
#
# Page 2 of 3
# ---
# Gmail - Custom Branded Jacket Order
#
# 2/3/24, 11:24 AM
#
# From: Hagoromo Chalk
#
# ==================================================
# sender: hagoromorphism@gmail.com
# receiver: shahmohnish@gmail.com
# date: 02/03/2024, 11:21
# convo_id: 1
# topics: ['orderDetails', 'buyer', 'lineItems']
#
# Dear AllSaints,
#
# Thank you for your detailed response and the breakdown of the pricing. We appreciate your willingness to offer a discount for our order.
#
# After careful consideration, we are pleased to accept the offer for the Blue and Pink Multi-Colored Hoodies at the discounted price of $270 per hoodie. We wish to purchase 15 small, 15 medium, and 20 large hoodies. We believe this will be a great addition to our event.
#
# Please provide us with the necessary information and steps to proceed with the order.
#
# We are excited to showcase these custom-branded hoodies at the LlamaIndex Hackathon.
#
# Looking forward to a successful collaboration.
#
# Best regards,
#
# LlamaIndex
#
# [Quoted text hidden]
#
# Page 3 of 3
#
# Agent Output:
#
# {
#     "lineItems": [
#         {
#             "itemNumber": 1,
#             "description": {
#                 "item": "Blue and Pink Multi-Colored Hoodie",
#                 "color": "Blue and Pink Multi-Colored",
#                 "size": "Small",
#                 "branding": "LlamaIndex",
#                 "discount": "10%",
#                 "discountedPrice": 270
#             },
#             "quantity": 15,
#             "unitPrice": 300,
#             "discount": 30,
#             "totalPrice": 4050
#         },
#         {
#             "itemNumber": 2,
#             "description": {
#                 "item": "Blue and Pink Multi-Colored Hoodie",
#                 "color": "Blue and Pink Multi-Colored",
#                 "size": "Medium",
#                 "branding": "LlamaIndex",
#                 "discount": "10%",
#                 "discountedPrice": 270
#             },
#             "quantity": 15,
#             "unitPrice": 300,
#             "discount": 30,
#             "totalPrice": 4050
#         },
#         {
#             "itemNumber": 3,
#             "description": {
#                 "item": "Blue and Pink Multi-Colored Hoodie",
#                 "color": "Blue and Pink Multi-Colored",
#                 "size": "Large",
#                 "branding": "LlamaIndex",
#                 "discount": "10%",
#                 "discountedPrice": 270
#             },
#             "quantity": 20,
#             "unitPrice": 300,
#             "discount": 30,
#             "totalPrice": 5400
#         }
#     ],
#     "orderDetails": {
#         "orderDate": "02/03/2024",
#         "orderNum": "1"
#     },
#     "buyer": {
#         "companyName": "LlamaIndex",
#         "pointOfContact": "Mohnish Shah",
#         "contactEmail": "shahmohnish@gmail.com",
#         "contactPhone": "",
#         "shippingAddress": ""
#     }
# }
# CPU times: user 65.7 ms, sys: 30.5 ms, total: 96.2 ms
# Wall time: 6.13 s
